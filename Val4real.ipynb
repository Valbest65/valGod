# %%
name=input('what is your name?___________')

score1 =int(input('whats your first score?______'))
score2=int(input('whats your secord secore?______'))
score3=int(input('whats your third secore?_______'))
secore=score1+score2+score3
avg=secore/3

if avg>=70 and avg<=100:
    grade="A"
elif avg>=60 and avg<70:
    grade="B"
elif avg>=50 and avg<60:
    grade="C"
elif avg>=40 and avg<50:
    grade="D"
elif avg>=30 and avg<40:
    grade="F"
else:
    grade= 'you are not a student'
print (f'{name}, your average score is {avg}, and your grade is {grade}')
# Out:
# Valreal, your average score is 83.33333333333333, and your grade is A

# %%
round (498.976899333, 3)
# Out:
# 498.977

# %% [markdown]
# 1.	Write a Python program that takes two numbers as input from the user and prints their sum.
# 2.	Write a Python program that takes a string input from the user and prints the string in reverse order.
# 3.	Write a Python program that asks the user for two numbers and prints their product.
# 4.	Write a Python program that asks the user for their first and last name, then prints their full name in uppercase.
# 5.	Create two variables, one for storing your name and another for storing your age. Print a sentence that combines these variables (e.g., "My name is [name] and I am [age] years old.").
# 6.	Write a Python program that asks the user for their favorite color and prints a message saying "Your favorite color is [color]"

# %%
# Take input from the use
user1=int(input('what is the first number  '))
user2=int(input('what is the second number '))
calculate=user1+user2
print (f'sum={calculate}')
# Out:
# sum=100

# %%
strings_input=input("type a word ")
reverse_word=''
for i in strings_input [: :-1]:
    reverse_word +=i
print(reverse_word)
# Out:
# cire

# %%
user1=float (input('enter the first number'))
user2=float (input('enter the second number'))
calculate=user1*user2
print(f'product= {calculate}')
# Out:
# product= 2250.0

# %%
first_name=input('enter the first name')
last_name=input('enter the last name')
fullname=first_name+ " "  +last_name
print (fullname.upper())
# Out:
# ERIC ERIC

# %%
name='wilson'
age=21
print(f'my name is {name}, i am {age} years old')
# Out:
# my name is wilson, i am 21 years old

# %%
user=input('enter your favorite colour')
print (f'your favourite colour is {user}')
# Out:
# your favourite colour is pink

# %% [markdown]
# Assignment  15
#
# Write a python code such that
# - Collect input from the user
# - Print "Fizz" if the number is divisible by 3
# - Print "Buzz" if the number is divisible by 5
# - Print "FizzBuzz" if the number s divisible by both 3 and 5
# - Print "Prime" if the number is Prime instead of FizzBuzz.
#
# 2.
# write a python program that applies discounts based on the following conditions.
# - <50,000, no discount
# - between 50,000 and 100,000, 5% discount
# - upto 200,000, 10% discount
# - >200,000, 15% discount
# - Using string formating, print the original Price, the discount and the discounted price as below:
# "Hello Sally,
# Your original price was #70,000
# You got a 5% discount
# Your discounted price is #66,500
# Thank you for your patronage!"

# %%
def prime_number(s):
    for i in range (2, int (s**0.5) +1):
        if s % i !=0:
            return False
        return s>1
    #print (prime_number(s))
    
   # return s > 1 and all(s % i != 0 for i in range(2, int(s**0.5) + 1))
user =int (input ('input a number'))
if prime_number(user):
    print ('prime')
elif user % 5==0 and user % 3==0:
    print ('fizzbuzz')    
elif user % 5==0:
    print ('buzz')
elif user % 3==0:
    print ('fizz')

else:
    print (f' is not a anumber')
# Out:
# buzz
